# %%
Student_list = { 
"student1": { 
"ID": 221311001, 
"GPA": 3.47, 
"Merit Position": 87, 
"Grades": { 
"CSE 321": "A+", 
"CSE 323": "C+", 
"CSE 324": "A", 
"ECO 331": "A", 
"CSE 331": "A", 
"CSE 332": "A-", 
"CSE 333": "A-", 
"CSE 334": "A", 
"CSE 336": "B-", 
}, 
}, 
"student2": { 
"ID": 221311002, 
"GPA": 3.22, 
"Merit Position": 113, 
"Grades": { 
"CSE 321": "A+", 
"CSE 323": "B-", 
"CSE 324": "A-", 
"ECO 331": "A+", 
"CSE 331": "A-", 
"CSE 332": "A-", 
"CSE 333": "D", 
"CSE 334": "A", 
"CSE 336": "C+", 
}, 
}, 
"student3": { 
"ID": 221311003, 
"GPA": 3.07, 
"Merit Position": 129, 
"Grades": { 
"CSE 321": "A-", 
"CSE 323": "C+", 
"CSE 324": "A-", 
"ECO 331": "A-", 
            "CSE 331": "B", 
            "CSE 332": "B+", 
            "CSE 333": "B", 
            "CSE 334": "B", 
            "CSE 336": "C+", 
        }, 
    }, 
    "student4": { 
        "ID": 221311004, 
        "GPA": 3.25, 
        "Merit Position": 106, 
        "Grades": { 
            "CSE 321": "B+", 
            "CSE 323": "B", 
            "CSE 324": "A-", 
            "ECO 331": "A-", 
            "CSE 331": "A-", 
            "CSE 332": "D", 
            "CSE 333": "A", 
            "CSE 334": "B-", 
            "CSE 336": "B-", 
        }, 
    }, 
    "student5": { 
        "ID": 221311005, 
        "GPA": 3.90, 
        "Merit Position": 35, 
        "Grades": { 
            "CSE 321": "A+", 
            "CSE 323": "A-", 
            "CSE 324": "A+", 
            "ECO 331": "A+", 
            "CSE 331": "A+", 
            "CSE 332": "A+", 
            "CSE 333": "A+", 
            "CSE 334": "A+", 
            "CSE 336": "A", 
        }, 
    }, 
    "student6": { 
        "ID": 221311006, 
        "GPA": 3.94, 
        "Merit Position": 25, 
        "Grades": { 
            "CSE 321": "A+", 
            "CSE 323": "A+", 
            "CSE 324": "A+", 
            "ECO 331": "A", 
            "CSE 331": "A+", 
            "CSE 332": "A+", 
            "CSE 333": "A+", 
            "CSE 334": "A+", 
            "CSE 336": "A-", 
        }, 
    }, 
    "student7": { 
        "ID": 221311007, 
        "GPA": 3.90, 
        "Merit Position": 36, 
        "Grades": { 
            "CSE 321": "A+", 
            "CSE 323": "A", 
            "CSE 324": "A+", 
            "ECO 331": "A+", 
            "CSE 331": "A+", 
            "CSE 332": "A+", 
            "CSE 333": "A+", 
            "CSE 334": "A+", 
            "CSE 336": "B", 
        }, 
    }, 
    "student8": { 
        "ID": 221311009, 
        "GPA": 3.69, 
        "Merit Position": 62, 
        "Grades": { 
            "CSE 321": "A", 
            "CSE 323": "B+", 
            "CSE 324": "A-", 
            "ECO 331": "A-", 
            "CSE 331": "A+", 
            "CSE 332": "A+", 
            "CSE 333": "A+", 
            "CSE 334": "A+", 
            "CSE 336": "B", 
        }, 
    }, 
    "student9": { 
        "ID": 221311010, 
        "GPA": 3.96, 
        "Merit Position": 22, 
        "Grades": { 
            "CSE 321": "A+", 
            "CSE 323": "A", 
            "CSE 324": "A+", 
            "ECO 331": "A+", 
            "CSE 331": "A+", 
            "CSE 332": "A+", 
            "CSE 333": "A+", 
            "CSE 334": "A+", 
            "CSE 336": "A+", 
        }, 
    }, 
    "student10": { 
        "ID": 221311011, 
        "GPA": 3.99, 
        "Merit Position": 15, 
        "Grades": { 
            "CSE 321": "A+", 
            "CSE 323": "A+", 
            "CSE 324": "A+", 
            "ECO 331": "A+", 
            "CSE 331": "A+", 
            "CSE 332": "A+", 
            "CSE 333": "A+", 
            "CSE 334": "A+", 
            "CSE 336": "A", 
        }, 
    }, 
    "student11": { 
        "ID": 221311012, 
        "GPA": 1.96, 
        "Merit Position": 0, 
        "Grades": { 
            "CSE 321": "C", 
            "CSE 323": "F", 
            "CSE 324": "A", 
            "ECO 331": "B+", 
            "CSE 331": "B", 
            "CSE 332": "B+", 
            "CSE 333": "F", 
            "CSE 334": "B+", 
            "CSE 336": "B-", 
        }, 
    }, 
    "student12": { 
        "ID": 221311013, 
        "GPA": 3.53, 
        "Merit Position": 83, 
        "Grades": { 
            "CSE 321": "A+", 
            "CSE 323": "B-", 
            "CSE 324": "A-", 
            "ECO 331": "A", 
            "CSE 331": "A", 
            "CSE 332": "A", 
            "CSE 333": "A-", 
            "CSE 334": "A", 
            "CSE 336": "B", 
        }, 
    }, 
    "student13": { 
        "ID": 221311014, 
        "GPA": 3.50, 
        "Merit Position": 85, 
        "Grades": { 
            "CSE 321": "A+", 
            "CSE 323": "B-", 
            "CSE 324": "A+", 
            "ECO 331": "A-", 
            "CSE 331": "B+", 
            "CSE 332": "A", 
            "CSE 333": "A+", 
            "CSE 334": "B+", 
            "CSE 336": "B", 
        }, 
    }, 
    "student14": { 
        "ID": 221311015, 
        "GPA": 3.36, 
        "Merit Position": 98, 
        "Grades": { 
            "CSE 321": "A+", 
            "CSE 323": "C+", 
            "CSE 324": "A+", 
            "ECO 331": "A", 
            "CSE 331": "A-", 
            "CSE 332": "A+", 
            "CSE 333": "B", 
            "CSE 334": "B+", 
            "CSE 336": "B-", 
        }, 
    }, 
    "student15": { 
        "ID": 221311016, 
        "GPA": 3.60, 
        "Merit Position": 75, 
        "Grades": { 
            "CSE 321": "A+", 
            "CSE 323": "B", 
            "CSE 324": "B+", 
            "ECO 331": "A", 
            "CSE 331": "A+", 
            "CSE 332": "A", 
            "CSE 333": "A+", 
            "CSE 334": "B", 
            "CSE 336": "C", 
        }, 
    }, 
    "student16": { 
        "ID": 221311017, 
        "GPA": 3.67, 
        "Merit Position": 67, 
        "Grades": { 
            "CSE 321": "A+", 
            "CSE 323": "A", 
            "CSE 324": "A", 
            "ECO 331": "A", 
            "CSE 331": "A+", 
            "CSE 332": "A-", 
            "CSE 333": "A-", 
            "CSE 334": "B+", 
            "CSE 336": "C", 
        }, 
    }, 
    "student17": { 
        "ID": 221311018, 
        "GPA": 3.99, 
        "Merit Position": 17, 
        "Grades": { 
            "CSE 321": "A+", 
            "CSE 323": "A+", 
            "CSE 324": "A+", 
            "ECO 331": "A+", 
            "CSE 331": "A+", 
            "CSE 332": "A", 
            "CSE 333": "A+", 
            "CSE 334": "A+", 
            "CSE 336": "A+", 
        }, 
    }, 
    "student18": { 
        "ID": 221311019, 
        "GPA": 3.78, 
        "Merit Position": 54, 
        "Grades": { 
            "CSE 321": "A+", 
            "CSE 323": "B+", 
            "CSE 324": "A+", 
            "ECO 331": "A+", 
            "CSE 331": "A+", 
            "CSE 332": "A+", 
            "CSE 333": "A+", 
            "CSE 334": "A-", 
            "CSE 336": "B-", 
        }, 
    }, 
    "student19": { 
        "ID": 221311020, 
        "GPA": 3.31, 
        "Merit Position": 103, 
        "Grades": { 
            "CSE 321": "A-", 
            "CSE 323": "C+", 
            "CSE 324": "A+", 
            "ECO 331": "A-", 
            "CSE 331": "B-", 
            "CSE 332": "A+", 
            "CSE 333": "A", 
            "CSE 334": "A-", 
            "CSE 336": "A-", 
        }, 
    }, 
    "student20": { 
        "ID": 221311021, 
        "GPA": 4.00, 
        "Merit Position": 6, 
        "Grades": { 
            "CSE 321": "A+", 
            "CSE 323": "A+", 
            "CSE 324": "A+", 
            "ECO 331": "A+", 
            "CSE 331": "A+", 
            "CSE 332": "A+", 
            "CSE 333": "A+", 
            "CSE 334": "A+", 
            "CSE 336": "A+", 
        }, 
    }, 
    "student21": { 
        "ID": 221311022, 
        "GPA": 3.96, 
        "Merit Position": 21, 
        "Grades": { 
            "CSE 321": "A+", 
            "CSE 323": "A", 
            "CSE 324": "A+", 
            "ECO 331": "A+", 
            "CSE 331": "A+", 
            "CSE 332": "A+", 
            "CSE 333": "A+", 
            "CSE 334": "A+", 
            "CSE 336": "A+", 
        }, 
    }, 
    "student22": { 
        "ID": 221311023, 
        "GPA": 4.00, 
        "Merit Position": 1, 
        "Grades": { 
            "CSE 321": "A+", 
            "CSE 323": "A+", 
            "CSE 324": "A+", 
            "ECO 331": "A+", 
            "CSE 331": "A+", 
            "CSE 332": "A+", 
            "CSE 333": "A+", 
            "CSE 334": "A+", 
            "CSE 336": "A+", 
        }, 
    }, 
    "student23": { 
        "ID": 221311024, 
        "GPA": 3.15, 
        "Merit Position": 118, 
        "Grades": { 
            "CSE 321": "B+", 
            "CSE 323": "C+", 
            "CSE 324": "A", 
            "ECO 331": "A", 
            "CSE 331": "C+", 
            "CSE 332": "A+", 
            "CSE 333": "B+", 
            "CSE 334": "A", 
            "CSE 336": "B+", 
        }, 
    }, 
    "student24": { 
        "ID": 221311025, 
        "GPA": 2.89, 
        "Merit Position": 138, 
        "Grades": { 
            "CSE 321": "C+", 
            "CSE 323": "C", 
            "CSE 324": "A+", 
            "ECO 331": "B", 
            "CSE 331": "B", 
            "CSE 332": "A+", 
            "CSE 333": "C+", 
            "CSE 334": "A", 
            "CSE 336": "A-", 
        }, 
    }, 
    "student25": { 
        "ID": 221311026, 
        "GPA": 2.64, 
        "Merit Position": 148, 
        "Grades": { 
            "CSE 321": "D", 
            "CSE 323": "C", 
            "CSE 324": "A", 
            "ECO 331": "B+", 
            "CSE 331": "B", 
            "CSE 332": "B", 
            "CSE 333": "D", 
            "CSE 334": "B+", 
            "CSE 336": "B+", 
        }, 
    }, 
    "student26": { 
        "ID": 221311027, 
        "GPA": 2.96, 
        "Merit Position": 135, 
        "Grades": { 
            "CSE 321": "B+", 
            "CSE 323": "C", 
            "CSE 324": "A-", 
            "ECO 331": "B+", 
            "CSE 331": "B", 
            "CSE 332": "B+", 
            "CSE 333": "B", 
            "CSE 334": "C+", 
            "CSE 336": "B", 
        }, 
    }, 
    "student27": { 
        "ID": 221311028, 
        "GPA": 3.04, 
        "Merit Position": 130, 
        "Grades": { 
            "CSE 321": "B", 
            "CSE 323": "D", 
            "CSE 324": "A+", 
            "ECO 331": "B+", 
            "CSE 331": "B", 
            "CSE 332": "A", 
            "CSE 333": "B", 
            "CSE 334": "A", 
            "CSE 336": "A", 
        }, 
    }, 
    "student28": { 
        "ID": 221311029, 
        "GPA": 2.94, 
        "Merit Position": 136, 
        "Grades": { 
            "CSE 321": "B", 
            "CSE 323": "C", 
            "CSE 324": "A-", 
            "ECO 331": "A-", 
            "CSE 331": "B-", 
            "CSE 332": "A", 
            "CSE 333": "B", 
            "CSE 334": "B-", 
            "CSE 336": "B", 
        }, 
    }, 
    "student29": { 
        "ID": 221311030, 
        "GPA": 3.53, 
        "Merit Position": 84, 
        "Grades": { 
            "CSE 321": "A", 
            "CSE 323": "B", 
            "CSE 324": "A", 
            "ECO 331": "A-", 
            "CSE 331": "A-", 
            "CSE 332": "B+", 
            "CSE 333": "A", 
            "CSE 334": "A-", 
            "CSE 336": "A+", 
        }, 
    }, 
    "student30": { 
        "ID": 221311031, 
        "GPA": 3.81, 
        "Merit Position": 53, 
        "Grades": { 
            "CSE 321": "A+", 
            "CSE 323": "A-", 
            "CSE 324": "A+", 
            "ECO 331": "A-", 
            "CSE 331": "A+", 
            "CSE 332": "A+", 
            "CSE 333": "A", 
            "CSE 334": "A", 
            "CSE 336": "A+", 
        }, 
    }, 
    "student31": { 
        "ID": 221311032, 
        "GPA": 3.07, 
        "Merit Position": 128, 
        "Grades": { 
            "CSE 321": "B-", 
            "CSE 323": "D", 
            "CSE 324": "A+", 
            "ECO 331": "B", 
            "CSE 331": "A-", 
            "CSE 332": "B+", 
            "CSE 333": "A-", 
            "CSE 334": "B", 
            "CSE 336": "A", 
        }, 
    }, 
    "student32": { 
        "ID": 221311033, 
        "GPA": 3.21, 
        "Merit Position": 114, 
        "Grades": {"CSE 321": "A", 
            "CSE 323": "C", 
            "CSE 324": "A-", 
            "ECO 331": "A-", 
            "CSE 331": "A", 
            "CSE 332": "A", 
            "CSE 333": "C+", 
            "CSE 334": "B", 
            "CSE 336": "A", 
        }, 
    }, 
    "student33": { 
        "ID": 221311034, 
        "GPA": 3.85, 
        "Merit Position": 48, 
        "Grades": { 
            "CSE 321": "A+", 
            "CSE 323": "A", 
            "CSE 324": "A+", 
            "ECO 331": "A", 
            "CSE 331": "A+", 
            "CSE 332": "A+", 
            "CSE 333": "A-", 
            "CSE 334": "A+", 
            "CSE 336": "A+", 
        }, 
    }, 
    "student34": { 
        "ID": 221311035, 
        "GPA": 3.97, 
        "Merit Position": 18, 
        "Grades": { 
            "CSE 321": "A+", 
            "CSE 323": "A+", 
            "CSE 324": "A+", 
            "ECO 331": "A", 
            "CSE 331": "A+", 
            "CSE 332": "A+", 
            "CSE 333": "A+", 
            "CSE 334": "A+", 
            "CSE 336": "A+", 
        }, 
    }, 
    "student35": { 
        "ID": 221311036, 
        "GPA": 3.68, 
        "Merit Position": 64, 
        "Grades": { 
            "CSE 321": "A+", 
            "CSE 323": "A-", 
            "CSE 324": "A-", 
            "ECO 331": "A-", 
            "CSE 331": "A-", 
            "CSE 332": "A-", 
            "CSE 333": "A+", 
            "CSE 334": "A", 
            "CSE 336": "A-", 
        }, 
    }, 
    "student36": { 
        "ID": 221311037, 
        "GPA": 2.13, 
        "Merit Position": 156, 
        "Grades": { 
            "CSE 321": "F", 
            "CSE 323": "D", 
            "CSE 324": "A", 
            "ECO 331": "B+", 
            "CSE 331": "C", 
            "CSE 332": "B+", 
            "CSE 333": "D", 
            "CSE 334": "B-", 
            "CSE 336": "B+", 
        }, 
    }, 
    "student37": { 
        "ID": 221311039, 
        "GPA": 3.92, 
        "Merit Position": 33, 
        "Grades": { 
            "CSE 321": "A+", 
            "CSE 323": "A+", 
            "CSE 324": "A", 
            "ECO 331": "A-", 
            "CSE 331": "A+", 
            "CSE 332": "A+", 
            "CSE 333": "A+", 
            "CSE 334": "A+", 
            "CSE 336": "A", 
        }, 
    }, 
    "student38": { 
        "ID": 221311040, 
        "GPA": 3.94, 
        "Merit Position": 24, 
        "Grades": { 
            "CSE 321": "A+", 
            "CSE 323": "A", 
            "CSE 324": "A+", 
            "ECO 331": "A+", 
            "CSE 331": "A+", 
            "CSE 332": "A+", 
            "CSE 333": "A+", 
            "CSE 334": "A+", 
            "CSE 336": "A", 
        }, 
    }, 
} 
 
def find_student_result_by_id(Student_id): 
    for Student in Student_list.values(): 
        if Student['ID'] == Student_id: 
            return Student 
    return "Student Result Not Found" 
 
Search_ID = 221311010 
print(find_student_result_by_id(Search_ID))
# Out:
# {'ID': 221311010, 'GPA': 3.96, 'Merit Position': 22, 'Grades': {'CSE 321': 'A+', 'CSE 323': 'A', 'CSE 324': 'A+', 'ECO 331': 'A+', 'CSE 331': 'A+', 'CSE 332': 'A+', 'CSE 333': 'A+', 'CSE 334': 'A+', 'CSE 336': 'A+'}}
